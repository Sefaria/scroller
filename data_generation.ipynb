# %%
import django
django.setup()

from sefaria.model import *

# %%
slugs = ["shabbat", "rosh-chodesh", "rosh-hashanah", "yom-kippur", "sukkot", "shemini-atzeret", "simchat-torah", "chanukkah", "tu-bshvat", "purim", "passover", "shavuot", "tisha-bav", "fasting", "tu-bav", "lag-baomer", "sefirat-haomer", "the-ten-days-of-repentance", "shabbat-hagadol", "high-holidays", "seder", "new-year", "yom-yerushalayim", "fast-of-gedaliah", "asarah-betevet", "yom-haatzmaut", "sigd", "elul", "four-questions", "the-four-children", "the-four-expressions-of-redemption", "fast-of-gedaliah", "hoshana-rabbah", "the-patriarchs", "abigail", "avishai", "abner", "abraham", "absalom", "achitofel", "adoniah", "adam", "adam-and-eve", "aaron", "ahab", "ahaz", "jezebel", "elijah", "elimelech", "eliezer", "eliphaz", "elisheba", "elisha", "eleazar", "elkanah", "the-matriarchs", "asa", "esther", "ephraim", "aram", "boaz", "balaam", "belshazzar", "benjamin", "baruch-the-son-of-neriah", "gad", "gechazi", "the-midwives", "goliath", "deborah", "doeg", "king-david", "the-spies", "dinah", "dan", "daniel", "daryavesh", "abel", "hagar", "hoshea", "haman", "vashti", "zevulun", "zechariah", "zimri", "zeresh", "habakkuk", "chur", "hezekiah", "hiram", "ham", "hannah", "enoch-the-son-of-jared", "judah", "judith", "jeconiah", "jehoiakim", "jonadab-the-son-of-rechab", "yehonatan", "joshua", "jehoshaphat", "joab", "joash-(king-of-judah) ", "jochebed", "jonah", "joseph", "ezekiel", "yael-the-wife-of-chever-the-kenite", "jacob", "japeth1", "jephthah", "isaac-and-esau", "isaac", "yerovam-(son-of-nebat) ", "yokheved", "moses", "jeremiah", "jesse", "ishmael", "isaiah", "issachar", "yitro", "cyrus", "caleb-the-son-of-jephunneh", "leah", "lot", "lilith", "lamech", "michiyahu", "michal", "malachi", "melchizedek", "menasseh-(king-of-judah) ", "menasseh-(son-of-jacob) ", "mordekhai", "miriam", "nebuchadnezzar", "naboth", "nabal", "nadav-and-avihu", "noah", "nehemiah", "nimrod", "naomi", "naaman", "nephilim", "naphtali", "sisera", "sennacherib", "serah-the-daughter-of-asher", "iddo", "obadiah", "og", "uzziah", "ezra", "achan", "the-sons-of-eli", "eli", "amos", "amalek", "amram", "amasa", "ephron", "er-the-firstborn-son-of-judah", "esau", "potiphar", "the-concubine-of-geva", "pinchas", "pharaoh", "daughters-of-zelophehad", "zelophehad", "zipporah", "keturah", "cain", "the-sons-of-korach", "korach", "reuben", "rebecca", "ruth", "rahab", "rehoboam", "rachel", "king-saul", "king-solomon", "shmuel-(prophet) ", "simeon", "shimei", "samson", "tamar", "terach", "queen-of-sheba", "sarah", "josiah", "zedekiah", "eve", "betzalel", "bath-sheba", "shem", "gideon", "ahasuerus", "pharaohs-daughter", "ahitophel", "asher", "hananiah-mishael-and-azariah", "sihon",
# %%
topics = [Topic.init(_.strip()) for _ in slugs]
topics = [t for t in topics if t is not None]
objects = []
for t in topics:
  d = {
    "slug": t.slug,
    "en": t.get_primary_title(),
    "he": t.get_primary_title("he")    
  }
  itl = IntraTopicLink().load({"linkType": "displays-under", "fromTopic": t.slug})
  d["cat"] = itl.toTopic if itl else ""
  objects += [d]

# %%
objects
# Out:
# [{'slug': 'shabbat', 'en': 'Shabbat', 'he': 'שבת', 'cat': 'jewish-calendar2'},
#  {'slug': 'rosh-chodesh',
#   'en': 'Rosh Chodesh',
#   'he': 'ראש חודש',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'rosh-hashanah',
#   'en': 'Rosh Hashanah',
#   'he': 'ראש השנה',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'yom-kippur',
#   'en': 'Yom Kippur',
#   'he': 'יום כיפור',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'sukkot', 'en': 'Sukkot', 'he': 'סוכות', 'cat': 'jewish-calendar2'},
#  {'slug': 'shemini-atzeret',
#   'en': 'Shemini Atzeret',
#   'he': 'שמיני עצרת',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'simchat-torah',
#   'en': 'Simchat Torah',
#   'he': 'שמחת תורה',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'chanukkah',
#   'en': 'Chanukkah',
#   'he': 'חנוכה',
#   'cat': 'jewish-calendar2'},
#  {'slug': 'purim', 'en': 'Purim', 'he': 'פורים', 'cat': 'jewish-calendar2'},
#  {'slug': 'passover',
#   'en': 'Passover',
#   'he': 'פסח',
#   'cat': 'jewish-calendar2'},
# ...

# %%
from collections import Counter

# Count values of cat key in object of array
c = Counter([o["cat"] for o in objects])
c
# Out:
# Counter({'stories': 158,
#          'biblical-figures': 140,
#          '': 83,
#          'values': 78,
#          'nature': 76,
#          'beliefs': 60,
#          'social-issues': 55,
#          'places': 54,
#          'talmudic-figures': 43,
#          'ritual-objects': 35,
#          'jewish-calendar2': 32,
#          'prayer': 29,
#          'food': 26,
#          'lifecycle': 18,
#          'philosophy': 18,
#          'supernatural': 10,
#          'health': 7,
#          'art': 6,
#          'halachic-principles': 5,
#          'history': 4,
#          'laws': 3,
#          'laws-of-impurity-and-purity': 3,
#          'agricultural-law': 2,
#          'family-law': 2,
#          'laws-of-prayer': 2,
#          'laws-of-optional-restrictions': 2,
#          'kabbalah': 1,
#          'human-ethics': 1,
#          'laws-of-the-calendar': 1,
#          'laws-of-worship-of-god': 1})
